# %% [markdown]
# ### Advanced RAG Pipeline

# %%
import os
import openai
openai.api_key = "" #insert your openai api key

# %%
from llama_index.core import SimpleDirectoryReader
documents = SimpleDirectoryReader(
    input_files=[r"C:\Users\deepa\Downloads\Josekutty_Jose_ML_Resume.pdf"]).load_data()
# Out:
# C:\Users\deepa\anaconda3\envs\jkutty\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
print(type(documents), "\n")
print(len(documents), "\n")
print(type(documents[0]))
print(documents[0])
# Out:
# <class 'list'>
#
# 2
#
# <class 'llama_index.core.schema.Document'>
# Doc ID: 3e05e1ae-01be-4db8-90a7-836830d72aa6
# Text: Josekutty Jose Machine Learning Engineer ♂phone+91 9745949352
# /envel⌢pejosekuttyjose08@gmail.com /linkedinLinkedIn /githubGitHub
# DagsHubὑ7LeetCode Proﬁle Summary Highly motivated Machine Learning
# Engineer over 6+ months of experience in Generative AI with a passion
# for building impactful AI solutions. Proven ability to design,
# develop, and deplo...

# %% [markdown]
# ### Basic RAG Pipeline

# %%
from llama_index.core import Document

document = Document(text="\n".join([doc.text for doc in documents]))

# %%
print(document.get_content())
# Out:
# Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com /linkedinLinkedIn /githubGitHub DagsHubὑ7LeetCode
# Proﬁle Summary
# Highly motivated Machine Learning Engineer over 6+ months of experience in Generative AI with a passion for building
# impactful AI solutions. Proven ability to design, develop, and deploy machine learning models across various domains.
# Skilled in data preprocessing, feature engineering, model selection, and hyperparameter tuning . Experience working with
# TensorFlow, PyTorch, and scikit-learn and Expertise in Quantization, Fine -tuning and improving the models performance.
# Eager to contribute to a team environment and continuously learn new technologies.
# Technical Skills
# Languages : Python, HTML, SQL, CSS, Neo4j, Cypher
# Frameworks : Tensorﬂow, Langchain, Streamlit, Pytorch , Fastapi
# Libraries : Excel, Pandas, Numpy, Scipy, Scikit-learn
# Tools & Platforms : Git, Dagshub,
# Data Visualization : Power BI, Tableau , Matplotlib, Seaborn
# Domain Skills : NLP, Statistical Modeling, Predictive Modeling, Data Analysis, Transformers, Machine Learning, Web
# Scraping, Generative AI, Deep Learning, CNN,Computer Vision, Artiﬁcial General Intelligence, AI
# Projects
# Detecting Air pollution in Mongolia using NLP |Apify, T5 Bert , LSTM, Deberta LLM, Hugging Face DagsHub
# •Collaborated with a 23- member team to develop and implement Environmental Sentinel on Social Media using
# sentiment analysisf or real-time air pollution monitoring in Mongolia.
# •Applied 3 key techniques: Market Research ,Data Collection , and Preprocessing , leading to successful Model
# Development
# •Successfully scraped and collected 75,469 pieces of Mongolian text from diverse sources, including Mongolian social
# media platforms and news channels.
# •Achieved sentiment analysis using LSTM with a focus on eﬃciency, utilizing minimal epochs due to lengthy
# processing time. Applied both categorical cross-entropy and binary cross-entropy loss functions, yielding 85%
# accuracy for categorical loss and 55% for binary loss.
# •Leveraged advanced LoRA techniques to ﬁne-tune LLM model, resulting in a remarkable 4%increase in accuracy
# within a mere 3training epochs.
# Interview Preparation Chatbot: |gtts , speech recognition , Chroma, DuckDB, Gemini. Live |DagsHub
# •Collaborated with a team of 30to develop a Chatbot web application for Interview preparation.
# •Collected 7000 questions and answers from diﬀerent sources for Non technical Jobs using Beautiful Soup(Web
# Scraping).
# •Implemented Speech Recognition technology to enable seamless interaction, enhancing the user experience
# through voice driven commands and responses using gttsand speech recognition.
# •Implemented RAG (Retrieval-Augmented Generation) with Chroma and DuckDB as vector databases for eﬃcient
# retrieval
# •The answers were evaluated using the vector similarity check.
# GemInsights: AI Automated Analyst |Autoviz, Gemini, llama index, Trulens Live |GitHub
# •Collaborated with a team of 6during a Gemini hackathon organized by LabLab, developing an automatic EDA
# (Exploratory Data Analysis) application using Gemini models.
# •Generated Insights from 7visualizations about the data and provide clarity in decision making
# •Evaluated the answers from the LLMs using Trulens .
# •The project were selected as the most upvoted project in the Gemini Hackathon.
# Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, gtts, Qlora, Peft, Chroma Github
# •Conversational Chatbot built Large Language Model llama2 and Langchain as Framework for visually impaired
# people.
# •Used Libraries like speech recognition and gtts for identifying speech and converting the text to speech which can
# be accessed by any type of people.
# •Model ﬁne-tuned on Mental Health Dataset using Qlora and Peft.
# Road Accident Dashboard |Tableau Link
# •Developed a comprehensive road accident dashboard using Tableau to analyze 2019 - 2022 accident data and
# improve decision-making processes.
# •Categorized accidents by 3 levels of severity and used visualizations to delve into the factors contributing to severe
# accidents.
# •Conducted comparative analyses of accident statistics across regions and time periods, facilitating the assessment of
# safety measures and interventions.
# Experience
# Omdena Nov 2023 – Present
# Junior Machine Learning Engineer Remote
# •Collaborated with 25+ AI Engineers, developers and clients in remote settings, ensuring seamless project execution
# and delivery of AI applications or products which solves real word problems.
# •Done web scraping using beautiful soup and Apify to collect 100,000 data from diﬀerent sources to create dataset
# for quality prediction.
# •Used Hugging face models like facebook/bart-large-mnli (zero-shot classiﬁcation ) and used language translation
# models like T-5,Bert and Deberta llm.
# •Implemented gtts and speech recognition models like whisper for better user experience and interaction.
# Education
# Data Science using python Dec 2023 - Jan 2024
# Brototype Ernakulam, Kerala
# Big data data Science using python and AWS Jan 2022 - Aug 2022
# Luminar Technolab Ernakulam, Kerala
# B.com with Logistics and Supply Chain , CGPA : 6 2018 - 2021
# Kristu Jayanti College Bangalore, Karnataka

# %%
from llama_index.core import VectorStoreIndex
from llama_index.core import ServiceContext
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo",temperature=0.1,api_key="")
service_context = ServiceContext.from_defaults(llm=llm,embed_model="local:BAAI/bge-small-en-v1.5")

index = VectorStoreIndex.from_documents([document],
                                        service_context=service_context)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_20264\1420247856.py:6: DeprecationWarning: Call to deprecated class method from_defaults. (ServiceContext is deprecated, please use `llama_index.settings.Settings` instead.) -- Deprecated since version 0.10.0.
#   service_context = ServiceContext.from_defaults(llm=llm,embed_model="local:BAAI/bge-small-en-v1.5")

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What is his mobile number ?")

# %%
print(str(response))
# Out:
# +91 9745949352

# %% [markdown]
# ### Evaluation Step using TruLens

# %%
eval_questions = []
with open("evaluation_question.txt","r") as file:
    for line in file:
        item = line.strip()
        print(item)
        eval_questions.append(item)
print(eval_questions)
# Out:
# What are the projects done by Josekutty Jose when he was working with Omdena ?
# what are qualifications of Josekutty and is he coming from a computer science background ?
# What are Skills known by Josekutty ?
# Is he having the relevant experience to become an Junior Machine Learing Engineer ,if yes what is his experience
# How long Josekutty was studing Data science ?
# ['What are the projects done by Josekutty Jose when he was working with Omdena ?', 'what are qualifications of Josekutty and is he coming from a computer science background ?', 'What are Skills known by Josekutty ?', 'Is he having the relevant experience to become an Junior Machine Learing Engineer ,if yes what is his experience', 'How long Josekutty was studing Data science ?']

# %%
#Create your own questions
new_question = "For what Job roles Josekutty can apply for ?"
eval_questions.append(new_question)
print(eval_questions)
# Out:
# ['What are the projects done by Josekutty Jose when he was working with Omdena ?', 'what are qualifications of Josekutty and is he coming from a computer science background ?', 'What are Skills known by Josekutty ?', 'Is he having the relevant experience to become an Junior Machine Learing Engineer ,if yes what is his experience', 'How long Josekutty was studing Data science ?', 'For what Job roles Josekutty can apply for ?']

# %%
from trulens_eval import Tru
tru = Tru()

tru.reset_database()
# Out:
# %s Tru initialized with db url %s . 🦑 sqlite:///default.sqlite
# 🛑 Secret keys may be written to the database. See the `database_redact_keys` option of Tru` to prevent this.

# %%
from utils import get_prebuilt_trulens_recorder

tru_recorder = get_prebuilt_trulens_recorder(query_engine,
                                             app_id="Direct Query Engine")
# Out:
# ✅ In Answer Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Answer Relevance, input response will be set to __record__.main_output or `Select.RecordOutput` .
# ✅ In Context Relevance, input prompt will be set to __record__.main_input or `Select.RecordInput` .
# ✅ In Context Relevance, input response will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input source will be set to __record__.app.query.rets.source_nodes[:].node.text .
# ✅ In Groundedness, input statement will be set to __record__.main_output or `Select.RecordOutput` .
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\deepa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
with tru_recorder as recording:
    for question in eval_questions:
        response = query_engine.query(question)
# Out:
# Groundedness per statement in source:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 with tru_recorder as recording:
#       2     for question in eval_questions:
#       3         response = query_engine.query(question)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\app.py:1034, in App.__exit__(self, exc_type, exc_value, exc_tb)
#    1031 self.recording_contexts.reset(ctx.token)
#    1033 if exc_type is not None:
# -> 1034     raise exc_value
#    1036 return
#
# Cell In[14], line 3
#       1 with tru_recorder as recording:
#       2     for question in eval_questions:
# ----> 3         response = query_engine.query(question)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:562, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     556     # If stack has only 1 thing on it, we are looking at a "root
#     557     # call". Create a record of the result and notify the app:
#     559     if len(stack) == 1:
#     560         # If this is a root call, notify app to add the completed record
#     561         # into its containers:
# --> 562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#     565             sig=sig,
#     566             bindings=bindings,
#     567             ret=rets,
#     568             error=error,
#     569             perf=Perf(start_time=start_time, end_time=end_time),
#     570             cost=cost,
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
#     575     raise error
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\app.py:1108, in App.on_add_record(self, ctx, func, sig, bindings, ret, error, perf, cost, existing_record)
#    1105 if error is not None:
#    1106     # May block on DB.
#    1107     self._handle_error(record=record, error=error)
# -> 1108     raise error
#    1110 # Will block on DB, but not on feedback evaluation, depending on
#    1111 # FeedbackMode:
#    1112 record.feedback_and_future_results = self._handle_record(record=record)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\base\base_query_engine.py:53, in BaseQueryEngine.query(self, str_or_query_bundle)
#      51     if isinstance(str_or_query_bundle, str):
#      52         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 53     query_result = self._query(str_or_query_bundle)
#      54 dispatch_event(QueryEndEvent())
#      55 return query_result
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:190, in RetrieverQueryEngine._query(self, query_bundle)
#     186 with self.callback_manager.event(
#     187     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     188 ) as query_event:
#     189     nodes = self.retrieve(query_bundle)
# --> 190     response = self._response_synthesizer.synthesize(
#     191         query=query_bundle,
#     192         nodes=nodes,
#     193     )
#     194     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     196 return response
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\base.py:242, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     236     query = QueryBundle(query_str=query)
#     238 with self._callback_manager.event(
#     239     CBEventType.SYNTHESIZE,
#     240     payload={EventPayload.QUERY_STR: query.query_str},
#     241 ) as event:
# --> 242     response_str = self.get_response(
#     243         query_str=query.query_str,
#     244         text_chunks=[
#     245             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     246         ],
#     247         **response_kwargs,
#     248     )
#     250     additional_source_nodes = additional_source_nodes or []
#     251     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:183, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     179 for text_chunk in text_chunks:
#     180     if prev_response is None:
#     181         # if this is the first chunk, and text chunk already
#     182         # is an answer, then return it
# --> 183         response = self._give_response_single(
#     184             query_str, text_chunk, **response_kwargs
#     185         )
#     186     else:
#     187         # refine response if possible
#     188         response = self._refine_response_single(
#     189             prev_response, query_str, text_chunk, **response_kwargs
#     190         )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:238, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     234 if response is None and not self._streaming:
#     235     try:
#     236         structured_response = cast(
#     237             StructuredRefineResponse,
# --> 238             program(
#     239                 context_str=cur_text_chunk,
#     240                 **response_kwargs,
#     241             ),
#     242         )
#     243         query_satisfied = structured_response.query_satisfied
#     244         if query_satisfied:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:84, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      82     answer = answer.json()
#      83 else:
# ---> 84     answer = self._llm.predict(
#      85         self._prompt,
#      86         **kwds,
#      87     )
#      88 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\llm.py:430, in LLM.predict(self, prompt, **prompt_args)
#     428 if self.metadata.is_chat_model:
#     429     messages = self._get_messages(prompt, **prompt_args)
# --> 430     chat_response = self.chat(messages)
#     431     output = chat_response.message.content or ""
#     432 else:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\callbacks.py:144, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     128 dispatcher.event(
#     129     LLMChatStartEvent(
#     130         model_dict=_self.to_dict(),
#    (...)
#     134     )
#     135 )
#     136 event_id = callback_manager.on_event_start(
#     137     CBEventType.LLM,
#     138     payload={
#    (...)
#     142     },
#     143 )
# --> 144 f_return_val = f(_self, messages, **kwargs)
#     146 if isinstance(f_return_val, Generator):
#     147     # intercept the generator and add a callback to the end
#     148     def wrapped_gen() -> ChatResponseGen:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:296, in OpenAI.chat(self, messages, **kwargs)
#     294 else:
#     295     chat_fn = completion_to_chat_decorator(self._complete)
# --> 296 return chat_fn(messages, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     323     retry_exc = self.retry_error_cls(fut)
#     324     if self.reraise:
# --> 325         raise retry_exc.reraise()
#     326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:158, in RetryError.reraise(self)
#     156 def reraise(self) -> t.NoReturn:
#     157     if self.last_attempt.failed:
# --> 158         raise self.last_attempt.result()
#     159     raise self
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:362, in OpenAI._chat(self, messages, **kwargs)
#     360 client = self._get_client()
#     361 message_dicts = to_openai_message_dicts(messages)
# --> 362 response = client.chat.completions.create(
#     363     messages=message_dicts,
#     364     stream=False,
#     365     **self._get_model_kwargs(**kwargs),
#     366 )
#     367 openai_message = response.choices[0].message
#     368 message = from_openai_message(openai_message)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:668, in Endpoint.wrap_function.<locals>.tru_wrapper(*args, **kwargs)
#     658 logger.debug(
#     659     "Calling instrumented method %s of type %s, "
#     660     "iscoroutinefunction=%s, "
#    (...)
#     663     inspect.isasyncgenfunction(func)
#     664 )
#     666 # Get the result of the wrapped function:
# --> 668 response = func(*args, **kwargs)
#     670 bindings = inspect.signature(func).bind(*args, **kwargs)
#     672 # Get all of the callback classes suitable for handling this
#     673 # call. Note that we stored this in the INSTRUMENT attribute of
#     674 # the wrapper method.
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\resources\chat\completions.py:579, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     577     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     578 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 579     return self._post(
#     580         "/chat/completions",
#     581         body=maybe_transform(
#     582             {
#     583                 "messages": messages,
#     584                 "model": model,
#     585                 "frequency_penalty": frequency_penalty,
#     586                 "function_call": function_call,
#     587                 "functions": functions,
#     588                 "logit_bias": logit_bias,
#     589                 "logprobs": logprobs,
#     590                 "max_tokens": max_tokens,
#     591                 "n": n,
#     592                 "presence_penalty": presence_penalty,
#     593                 "response_format": response_format,
#     594                 "seed": seed,
#     595                 "stop": stop,
#     596                 "stream": stream,
#     597                 "temperature": temperature,
#     598                 "tool_choice": tool_choice,
#     599                 "tools": tools,
#     600                 "top_logprobs": top_logprobs,
#     601                 "top_p": top_p,
#     602                 "user": user,
#     603             },
#     604             completion_create_params.CompletionCreateParams,
#     605         ),
#     606         options=make_request_options(
#     607             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     608         ),
#     609         cast_to=ChatCompletion,
#     610         stream=stream or False,
#     611         stream_cls=Stream[ChatCompletionChunk],
#     612     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1232, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1218 def post(
#    1219     self,
#    1220     path: str,
#    (...)
#    1227     stream_cls: type[_StreamT] | None = None,
#    1228 ) -> ResponseT | _StreamT:
#    1229     opts = FinalRequestOptions.construct(
#    1230         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1231     )
# -> 1232     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1012, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1009         err.response.read()
#    1011     log.debug("Re-raising status error")
# -> 1012     raise self._make_status_error_from_response(err.response) from None
#    1014 return self._process_response(
#    1015     cast_to=cast_to,
#    1016     options=options,
#    (...)
#    1019     stream_cls=stream_cls,
#    1020 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-n0G63sO89mOIG13HXDCrrwfQ on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
records, feedback = tru.get_records_and_feedback(app_ids=[])

# %%
records.head()
# Out:
#                 app_id                                           app_json  \
# 0  Direct Query Engine  {"tru_class_info": {"name": "TruLlama", "modul...
#
#                                                 type  \
# 0  RetrieverQueryEngine(llama_index.core.query_en...
#
#                                       record_id  \
# 0  record_hash_cf89af934e0138aa5d81e89bb42878d3
#
#                                                input  \
# 0  "What are the projects done by Josekutty Jose ...
#
#                                               output tags  \
# 0  "Josekutty Jose worked on two projects when he...    -
#
#                                          record_json  \
# 0  {"record_id": "record_hash_cf89af934e0138aa5d8...
#
#                                            cost_json  \
# 0  {"n_requests": 0, "n_successful_requests": 0, ...
#
#                                            perf_json  \
# 0  {"start_time": "2024-04-24T18:48:02.438221", "...
#
#                            ts  Answer Relevance  \
# 0  2024-04-24T18:48:08.981288               1.0
#
#                               Answer Relevance_calls  latency  total_tokens  \
# 0  [{'args': {'prompt': 'What are the projects do...        6             0
#
#    total_cost
# 0         0.0

# %%
from trulens_eval import Tru
tru = Tru()
# launches on http://localhost:8501/
tru.run_dashboard()
# Out:
# Starting dashboard ...
# Config file already exists. Skipping writing process.
# Credentials file already exists. Skipping writing process.
# Dashboard already running at path:   Network URL: http://192.168.1.11:8501
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ### Advance RAG Pipeline

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)

# %%
from utils import build_sentence_window_index

sentence_index = build_sentence_window_index(
    document,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="sentence_index"
)

# %%
from utils import get_sentence_window_query_engine

sentence_window_engine = get_sentence_window_query_engine(sentence_index)
# Out:
# config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# C:\Users\deepa\anaconda3\envs\jkutty\Lib\site-packages\huggingface_hub\file_download.py:148: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\deepa\.cache\huggingface\hub\models--BAAI--bge-reranker-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]

# %%
window_response = sentence_window_engine.query(
    "how do I get started on a personal project in AI?"
)
print(str(window_response))
# Out:
# To get started on a personal project in AI, you can begin by selecting a specific area of interest within artificial intelligence, such as natural language processing, computer vision, or predictive modeling. Next, familiarize yourself with relevant programming languages like Python and frameworks such as TensorFlow or PyTorch. It would also be beneficial to explore libraries like Pandas, NumPy, and Scikit-learn for data manipulation and model building. Once you have identified your project idea and equipped yourself with the necessary technical skills, you can start by defining the project scope, collecting and preprocessing data, selecting appropriate models, and iterating on model performance through techniques like hyperparameter tuning. Remember to leverage resources like online tutorials, forums, and documentation to guide you through the project implementation process.

# %%
tru.reset_database()

tru_recorder_sentence_window = get_prebuilt_trulens_recorder(
    sentence_window_engine,
    app_id = "Sentence Window Query Engine"
)

# %%
for question in eval_questions:
    with tru_recorder_sentence_window as recording:
        response = sentence_window_engine.query(question)
        print(question)
        print(str(response))
# Out:
# What are the projects done by Josekutty Jose when he was working with Omdena ?
# Josekutty Jose worked on two projects while at Omdena. The first project involved collaborating with a team to collect data through web scraping from various sources to create a dataset for quality prediction. The second project included utilizing Hugging Face models like facebook/bart-large-mnli for zero-shot classification and language translation models such as T-5, Bert, and Deberta llm. Additionally, he implemented gtts and speech recognition models like whisper to enhance user experience and interaction.
# Groundedness per statement in source:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 for question in eval_questions:
# ----> 2     with tru_recorder_sentence_window as recording:
#       3         response = sentence_window_engine.query(question)
#       4         print(question)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\app.py:1034, in App.__exit__(self, exc_type, exc_value, exc_tb)
#    1031 self.recording_contexts.reset(ctx.token)
#    1033 if exc_type is not None:
# -> 1034     raise exc_value
#    1036 return
#
# Cell In[26], line 3
#       1 for question in eval_questions:
#       2     with tru_recorder_sentence_window as recording:
# ----> 3         response = sentence_window_engine.query(question)
#       4         print(question)
#       5         print(str(response))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:562, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     556     # If stack has only 1 thing on it, we are looking at a "root
#     557     # call". Create a record of the result and notify the app:
#     559     if len(stack) == 1:
#     560         # If this is a root call, notify app to add the completed record
#     561         # into its containers:
# --> 562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#     565             sig=sig,
#     566             bindings=bindings,
#     567             ret=rets,
#     568             error=error,
#     569             perf=Perf(start_time=start_time, end_time=end_time),
#     570             cost=cost,
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
#     575     raise error
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\app.py:1108, in App.on_add_record(self, ctx, func, sig, bindings, ret, error, perf, cost, existing_record)
#    1105 if error is not None:
#    1106     # May block on DB.
#    1107     self._handle_error(record=record, error=error)
# -> 1108     raise error
#    1110 # Will block on DB, but not on feedback evaluation, depending on
#    1111 # FeedbackMode:
#    1112 record.feedback_and_future_results = self._handle_record(record=record)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\base\base_query_engine.py:53, in BaseQueryEngine.query(self, str_or_query_bundle)
#      51     if isinstance(str_or_query_bundle, str):
#      52         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 53     query_result = self._query(str_or_query_bundle)
#      54 dispatch_event(QueryEndEvent())
#      55 return query_result
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:190, in RetrieverQueryEngine._query(self, query_bundle)
#     186 with self.callback_manager.event(
#     187     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     188 ) as query_event:
#     189     nodes = self.retrieve(query_bundle)
# --> 190     response = self._response_synthesizer.synthesize(
#     191         query=query_bundle,
#     192         nodes=nodes,
#     193     )
#     194     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     196 return response
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\base.py:242, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     236     query = QueryBundle(query_str=query)
#     238 with self._callback_manager.event(
#     239     CBEventType.SYNTHESIZE,
#     240     payload={EventPayload.QUERY_STR: query.query_str},
#     241 ) as event:
# --> 242     response_str = self.get_response(
#     243         query_str=query.query_str,
#     244         text_chunks=[
#     245             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     246         ],
#     247         **response_kwargs,
#     248     )
#     250     additional_source_nodes = additional_source_nodes or []
#     251     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:183, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     179 for text_chunk in text_chunks:
#     180     if prev_response is None:
#     181         # if this is the first chunk, and text chunk already
#     182         # is an answer, then return it
# --> 183         response = self._give_response_single(
#     184             query_str, text_chunk, **response_kwargs
#     185         )
#     186     else:
#     187         # refine response if possible
#     188         response = self._refine_response_single(
#     189             prev_response, query_str, text_chunk, **response_kwargs
#     190         )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:238, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     234 if response is None and not self._streaming:
#     235     try:
#     236         structured_response = cast(
#     237             StructuredRefineResponse,
# --> 238             program(
#     239                 context_str=cur_text_chunk,
#     240                 **response_kwargs,
#     241             ),
#     242         )
#     243         query_satisfied = structured_response.query_satisfied
#     244         if query_satisfied:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:84, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      82     answer = answer.json()
#      83 else:
# ---> 84     answer = self._llm.predict(
#      85         self._prompt,
#      86         **kwds,
#      87     )
#      88 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\llm.py:430, in LLM.predict(self, prompt, **prompt_args)
#     428 if self.metadata.is_chat_model:
#     429     messages = self._get_messages(prompt, **prompt_args)
# --> 430     chat_response = self.chat(messages)
#     431     output = chat_response.message.content or ""
#     432 else:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\callbacks.py:144, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     128 dispatcher.event(
#     129     LLMChatStartEvent(
#     130         model_dict=_self.to_dict(),
#    (...)
#     134     )
#     135 )
#     136 event_id = callback_manager.on_event_start(
#     137     CBEventType.LLM,
#     138     payload={
#    (...)
#     142     },
#     143 )
# --> 144 f_return_val = f(_self, messages, **kwargs)
#     146 if isinstance(f_return_val, Generator):
#     147     # intercept the generator and add a callback to the end
#     148     def wrapped_gen() -> ChatResponseGen:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:296, in OpenAI.chat(self, messages, **kwargs)
#     294 else:
#     295     chat_fn = completion_to_chat_decorator(self._complete)
# --> 296 return chat_fn(messages, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     323     retry_exc = self.retry_error_cls(fut)
#     324     if self.reraise:
# --> 325         raise retry_exc.reraise()
#     326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:158, in RetryError.reraise(self)
#     156 def reraise(self) -> t.NoReturn:
#     157     if self.last_attempt.failed:
# --> 158         raise self.last_attempt.result()
#     159     raise self
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:362, in OpenAI._chat(self, messages, **kwargs)
#     360 client = self._get_client()
#     361 message_dicts = to_openai_message_dicts(messages)
# --> 362 response = client.chat.completions.create(
#     363     messages=message_dicts,
#     364     stream=False,
#     365     **self._get_model_kwargs(**kwargs),
#     366 )
#     367 openai_message = response.choices[0].message
#     368 message = from_openai_message(openai_message)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:668, in Endpoint.wrap_function.<locals>.tru_wrapper(*args, **kwargs)
#     658 logger.debug(
#     659     "Calling instrumented method %s of type %s, "
#     660     "iscoroutinefunction=%s, "
#    (...)
#     663     inspect.isasyncgenfunction(func)
#     664 )
#     666 # Get the result of the wrapped function:
# --> 668 response = func(*args, **kwargs)
#     670 bindings = inspect.signature(func).bind(*args, **kwargs)
#     672 # Get all of the callback classes suitable for handling this
#     673 # call. Note that we stored this in the INSTRUMENT attribute of
#     674 # the wrapper method.
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\resources\chat\completions.py:579, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     577     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     578 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 579     return self._post(
#     580         "/chat/completions",
#     581         body=maybe_transform(
#     582             {
#     583                 "messages": messages,
#     584                 "model": model,
#     585                 "frequency_penalty": frequency_penalty,
#     586                 "function_call": function_call,
#     587                 "functions": functions,
#     588                 "logit_bias": logit_bias,
#     589                 "logprobs": logprobs,
#     590                 "max_tokens": max_tokens,
#     591                 "n": n,
#     592                 "presence_penalty": presence_penalty,
#     593                 "response_format": response_format,
#     594                 "seed": seed,
#     595                 "stop": stop,
#     596                 "stream": stream,
#     597                 "temperature": temperature,
#     598                 "tool_choice": tool_choice,
#     599                 "tools": tools,
#     600                 "top_logprobs": top_logprobs,
#     601                 "top_p": top_p,
#     602                 "user": user,
#     603             },
#     604             completion_create_params.CompletionCreateParams,
#     605         ),
#     606         options=make_request_options(
#     607             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     608         ),
#     609         cast_to=ChatCompletion,
#     610         stream=stream or False,
#     611         stream_cls=Stream[ChatCompletionChunk],
#     612     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1232, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1218 def post(
#    1219     self,
#    1220     path: str,
#    (...)
#    1227     stream_cls: type[_StreamT] | None = None,
#    1228 ) -> ResponseT | _StreamT:
#    1229     opts = FinalRequestOptions.construct(
#    1230         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1231     )
# -> 1232     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1012, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1009         err.response.read()
#    1011     log.debug("Re-raising status error")
# -> 1012     raise self._make_status_error_from_response(err.response) from None
#    1014 return self._process_response(
#    1015     cast_to=cast_to,
#    1016     options=options,
#    (...)
#    1019     stream_cls=stream_cls,
#    1020 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-n0G63sO89mOIG13HXDCrrwfQ on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
tru.get_leaderboard(app_ids=[])
# Out:
#                               Answer Relevance  Context Relevance  latency  \
# app_id
# Sentence Window Query Engine               0.9               0.45     17.0
#
#                               total_cost
# app_id
# Sentence Window Query Engine         0.0

# %%
# launches on http://localhost:8501/
tru.run_dashboard()
# Out:
# Starting dashboard ...
# Config file already exists. Skipping writing process.
# Credentials file already exists. Skipping writing process.
# Dashboard already running at path:   Network URL: http://192.168.1.11:8501
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>

# %% [markdown]
# ### Auto-Merging Retrieval

# %%
from utils import build_automerging_index

automerging_index = build_automerging_index(
    documents,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="merging_index"
)

# %%
from utils import get_automerging_query_engine

automerging_query_engine = get_automerging_query_engine(
    automerging_index,
)

# %%
auto_merging_response = automerging_query_engine.query(
    "How do I build a portfolio of AI projects?"
)
print(str(auto_merging_response))
# Out:
# > Merging 5 nodes into parent node.
# > Parent node id: 10aa3f7f-7b7e-4eda-af8d-36bcd79b13d7.
# > Parent node text: Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com ...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 679389ae-c85d-4d94-9317-9e2d3378415b.
# > Parent node text: Applied both categorical cross-entropy and binary cross-entropy loss functions, yielding 85%
# accu...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 22b84a0c-f2c8-4d59-87bd-04a358210979.
# > Parent node text: Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, g...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f89628c7-0982-4d23-8187-72f7b56805d2.
# > Parent node text: Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: b0eff28a-dc94-4a80-b43c-60d14f26786d.
# > Parent node text: Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, g...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 auto_merging_response = automerging_query_engine.query(
#       2     "How do I build a portfolio of AI projects?"
#       3 )
#       4 print(str(auto_merging_response))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:421, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     414 if len(contexts) == 0:
#     415     # If no app wants this call recorded, run and return without
#     416     # instrumentation.
#     417     logger.debug(
#     418         "%s: no record found or requested, not recording.", query
#     419     )
# --> 421     return func(*args, **kwargs)
#     423 # If a wrapped method was called in this call stack, get the prior
#     424 # calls from this variable. Otherwise create a new chain stack. As
#     425 # another wrinke, the addresses of methods in the stack may vary
#     426 # from app to app that are watching this method. Hence we index the
#     427 # stacks by id of the call record list which is unique to each app.
#     428 ctx_stacks = get_first_local_in_call_stack(
#     429     key="stacks",
#     430     func=find_instrumented,
#     431     offset=1,
#     432     skip=caller_frame()
#     433 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\base\base_query_engine.py:53, in BaseQueryEngine.query(self, str_or_query_bundle)
#      51     if isinstance(str_or_query_bundle, str):
#      52         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 53     query_result = self._query(str_or_query_bundle)
#      54 dispatch_event(QueryEndEvent())
#      55 return query_result
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:190, in RetrieverQueryEngine._query(self, query_bundle)
#     186 with self.callback_manager.event(
#     187     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     188 ) as query_event:
#     189     nodes = self.retrieve(query_bundle)
# --> 190     response = self._response_synthesizer.synthesize(
#     191         query=query_bundle,
#     192         nodes=nodes,
#     193     )
#     194     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     196 return response
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\base.py:242, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     236     query = QueryBundle(query_str=query)
#     238 with self._callback_manager.event(
#     239     CBEventType.SYNTHESIZE,
#     240     payload={EventPayload.QUERY_STR: query.query_str},
#     241 ) as event:
# --> 242     response_str = self.get_response(
#     243         query_str=query.query_str,
#     244         text_chunks=[
#     245             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     246         ],
#     247         **response_kwargs,
#     248     )
#     250     additional_source_nodes = additional_source_nodes or []
#     251     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:421, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     414 if len(contexts) == 0:
#     415     # If no app wants this call recorded, run and return without
#     416     # instrumentation.
#     417     logger.debug(
#     418         "%s: no record found or requested, not recording.", query
#     419     )
# --> 421     return func(*args, **kwargs)
#     423 # If a wrapped method was called in this call stack, get the prior
#     424 # calls from this variable. Otherwise create a new chain stack. As
#     425 # another wrinke, the addresses of methods in the stack may vary
#     426 # from app to app that are watching this method. Hence we index the
#     427 # stacks by id of the call record list which is unique to each app.
#     428 ctx_stacks = get_first_local_in_call_stack(
#     429     key="stacks",
#     430     func=find_instrumented,
#     431     offset=1,
#     432     skip=caller_frame()
#     433 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:421, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     414 if len(contexts) == 0:
#     415     # If no app wants this call recorded, run and return without
#     416     # instrumentation.
#     417     logger.debug(
#     418         "%s: no record found or requested, not recording.", query
#     419     )
# --> 421     return func(*args, **kwargs)
#     423 # If a wrapped method was called in this call stack, get the prior
#     424 # calls from this variable. Otherwise create a new chain stack. As
#     425 # another wrinke, the addresses of methods in the stack may vary
#     426 # from app to app that are watching this method. Hence we index the
#     427 # stacks by id of the call record list which is unique to each app.
#     428 ctx_stacks = get_first_local_in_call_stack(
#     429     key="stacks",
#     430     func=find_instrumented,
#     431     offset=1,
#     432     skip=caller_frame()
#     433 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:183, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     179 for text_chunk in text_chunks:
#     180     if prev_response is None:
#     181         # if this is the first chunk, and text chunk already
#     182         # is an answer, then return it
# --> 183         response = self._give_response_single(
#     184             query_str, text_chunk, **response_kwargs
#     185         )
#     186     else:
#     187         # refine response if possible
#     188         response = self._refine_response_single(
#     189             prev_response, query_str, text_chunk, **response_kwargs
#     190         )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:238, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     234 if response is None and not self._streaming:
#     235     try:
#     236         structured_response = cast(
#     237             StructuredRefineResponse,
# --> 238             program(
#     239                 context_str=cur_text_chunk,
#     240                 **response_kwargs,
#     241             ),
#     242         )
#     243         query_satisfied = structured_response.query_satisfied
#     244         if query_satisfied:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:84, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      82     answer = answer.json()
#      83 else:
# ---> 84     answer = self._llm.predict(
#      85         self._prompt,
#      86         **kwds,
#      87     )
#      88 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\llm.py:430, in LLM.predict(self, prompt, **prompt_args)
#     428 if self.metadata.is_chat_model:
#     429     messages = self._get_messages(prompt, **prompt_args)
# --> 430     chat_response = self.chat(messages)
#     431     output = chat_response.message.content or ""
#     432 else:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:421, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     414 if len(contexts) == 0:
#     415     # If no app wants this call recorded, run and return without
#     416     # instrumentation.
#     417     logger.debug(
#     418         "%s: no record found or requested, not recording.", query
#     419     )
# --> 421     return func(*args, **kwargs)
#     423 # If a wrapped method was called in this call stack, get the prior
#     424 # calls from this variable. Otherwise create a new chain stack. As
#     425 # another wrinke, the addresses of methods in the stack may vary
#     426 # from app to app that are watching this method. Hence we index the
#     427 # stacks by id of the call record list which is unique to each app.
#     428 ctx_stacks = get_first_local_in_call_stack(
#     429     key="stacks",
#     430     func=find_instrumented,
#     431     offset=1,
#     432     skip=caller_frame()
#     433 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\callbacks.py:144, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     128 dispatcher.event(
#     129     LLMChatStartEvent(
#     130         model_dict=_self.to_dict(),
#    (...)
#     134     )
#     135 )
#     136 event_id = callback_manager.on_event_start(
#     137     CBEventType.LLM,
#     138     payload={
#    (...)
#     142     },
#     143 )
# --> 144 f_return_val = f(_self, messages, **kwargs)
#     146 if isinstance(f_return_val, Generator):
#     147     # intercept the generator and add a callback to the end
#     148     def wrapped_gen() -> ChatResponseGen:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:296, in OpenAI.chat(self, messages, **kwargs)
#     294 else:
#     295     chat_fn = completion_to_chat_decorator(self._complete)
# --> 296 return chat_fn(messages, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     323     retry_exc = self.retry_error_cls(fut)
#     324     if self.reraise:
# --> 325         raise retry_exc.reraise()
#     326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:158, in RetryError.reraise(self)
#     156 def reraise(self) -> t.NoReturn:
#     157     if self.last_attempt.failed:
# --> 158         raise self.last_attempt.result()
#     159     raise self
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:362, in OpenAI._chat(self, messages, **kwargs)
#     360 client = self._get_client()
#     361 message_dicts = to_openai_message_dicts(messages)
# --> 362 response = client.chat.completions.create(
#     363     messages=message_dicts,
#     364     stream=False,
#     365     **self._get_model_kwargs(**kwargs),
#     366 )
#     367 openai_message = response.choices[0].message
#     368 message = from_openai_message(openai_message)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:668, in Endpoint.wrap_function.<locals>.tru_wrapper(*args, **kwargs)
#     658 logger.debug(
#     659     "Calling instrumented method %s of type %s, "
#     660     "iscoroutinefunction=%s, "
#    (...)
#     663     inspect.isasyncgenfunction(func)
#     664 )
#     666 # Get the result of the wrapped function:
# --> 668 response = func(*args, **kwargs)
#     670 bindings = inspect.signature(func).bind(*args, **kwargs)
#     672 # Get all of the callback classes suitable for handling this
#     673 # call. Note that we stored this in the INSTRUMENT attribute of
#     674 # the wrapper method.
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\resources\chat\completions.py:579, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     577     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     578 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 579     return self._post(
#     580         "/chat/completions",
#     581         body=maybe_transform(
#     582             {
#     583                 "messages": messages,
#     584                 "model": model,
#     585                 "frequency_penalty": frequency_penalty,
#     586                 "function_call": function_call,
#     587                 "functions": functions,
#     588                 "logit_bias": logit_bias,
#     589                 "logprobs": logprobs,
#     590                 "max_tokens": max_tokens,
#     591                 "n": n,
#     592                 "presence_penalty": presence_penalty,
#     593                 "response_format": response_format,
#     594                 "seed": seed,
#     595                 "stop": stop,
#     596                 "stream": stream,
#     597                 "temperature": temperature,
#     598                 "tool_choice": tool_choice,
#     599                 "tools": tools,
#     600                 "top_logprobs": top_logprobs,
#     601                 "top_p": top_p,
#     602                 "user": user,
#     603             },
#     604             completion_create_params.CompletionCreateParams,
#     605         ),
#     606         options=make_request_options(
#     607             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     608         ),
#     609         cast_to=ChatCompletion,
#     610         stream=stream or False,
#     611         stream_cls=Stream[ChatCompletionChunk],
#     612     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1232, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1218 def post(
#    1219     self,
#    1220     path: str,
#    (...)
#    1227     stream_cls: type[_StreamT] | None = None,
#    1228 ) -> ResponseT | _StreamT:
#    1229     opts = FinalRequestOptions.construct(
#    1230         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1231     )
# -> 1232     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1012, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1009         err.response.read()
#    1011     log.debug("Re-raising status error")
# -> 1012     raise self._make_status_error_from_response(err.response) from None
#    1014 return self._process_response(
#    1015     cast_to=cast_to,
#    1016     options=options,
#    (...)
#    1019     stream_cls=stream_cls,
#    1020 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-n0G63sO89mOIG13HXDCrrwfQ on requests per day (RPD): Limit 200, Used 200, Requested 1. Please try again in 7m12s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
tru.reset_database()

tru_recorder_automerging = get_prebuilt_trulens_recorder(automerging_query_engine,
                                                         app_id="Automerging Query Engine")

# %%
for question in eval_questions:
    with tru_recorder_automerging as recording:
        response = automerging_query_engine.query(question)
        print(question)
        print(response)
# Out:
# > Merging 3 nodes into parent node.
# > Parent node id: 22b84a0c-f2c8-4d59-87bd-04a358210979.
# > Parent node text: Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, g...
#
# > Merging 6 nodes into parent node.
# > Parent node id: 10aa3f7f-7b7e-4eda-af8d-36bcd79b13d7.
# > Parent node text: Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 679389ae-c85d-4d94-9317-9e2d3378415b.
# > Parent node text: Applied both categorical cross-entropy and binary cross-entropy loss functions, yielding 85%
# accu...
#
# > Merging 1 nodes into parent node.
# > Parent node id: b0eff28a-dc94-4a80-b43c-60d14f26786d.
# > Parent node text: Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, g...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f89628c7-0982-4d23-8187-72f7b56805d2.
# > Parent node text: Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com ...
#
# What are the projects done by Josekutty Jose when he was working with Omdena ?
# Road Accident Dashboard using Tableau.
# Groundedness per statement in source:   0%|          | 0/1 [00:00<?, ?it/s]
# > Merging 5 nodes into parent node.
# > Parent node id: 10aa3f7f-7b7e-4eda-af8d-36bcd79b13d7.
# > Parent node text: Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com ...
#
# > Merging 3 nodes into parent node.
# > Parent node id: 22b84a0c-f2c8-4d59-87bd-04a358210979.
# > Parent node text: Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, g...
#
# > Merging 4 nodes into parent node.
# > Parent node id: 679389ae-c85d-4d94-9317-9e2d3378415b.
# > Parent node text: Applied both categorical cross-entropy and binary cross-entropy loss functions, yielding 85%
# accu...
#
# > Merging 2 nodes into parent node.
# > Parent node id: f89628c7-0982-4d23-8187-72f7b56805d2.
# > Parent node text: Josekutty Jose
# Machine Learning Engineer
# ♂phone+91 9745949352 /envel⌢pejosekuttyjose08@gmail.com ...
#
# > Merging 1 nodes into parent node.
# > Parent node id: b0eff28a-dc94-4a80-b43c-60d14f26786d.
# > Parent node text: Personal Projects
# GenEye: Your Mental Health Assistant |llama2, langchain , speech recognition, g...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 for question in eval_questions:
# ----> 2     with tru_recorder_automerging as recording:
#       3         response = automerging_query_engine.query(question)
#       4         print(question)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\app.py:1034, in App.__exit__(self, exc_type, exc_value, exc_tb)
#    1031 self.recording_contexts.reset(ctx.token)
#    1033 if exc_type is not None:
# -> 1034     raise exc_value
#    1036 return
#
# Cell In[33], line 3
#       1 for question in eval_questions:
#       2     with tru_recorder_automerging as recording:
# ----> 3         response = automerging_query_engine.query(question)
#       4         print(question)
#       5         print(response)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:562, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     556     # If stack has only 1 thing on it, we are looking at a "root
#     557     # call". Create a record of the result and notify the app:
#     559     if len(stack) == 1:
#     560         # If this is a root call, notify app to add the completed record
#     561         # into its containers:
# --> 562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#     565             sig=sig,
#     566             bindings=bindings,
#     567             ret=rets,
#     568             error=error,
#     569             perf=Perf(start_time=start_time, end_time=end_time),
#     570             cost=cost,
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
#     575     raise error
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\app.py:1108, in App.on_add_record(self, ctx, func, sig, bindings, ret, error, perf, cost, existing_record)
#    1105 if error is not None:
#    1106     # May block on DB.
#    1107     self._handle_error(record=record, error=error)
# -> 1108     raise error
#    1110 # Will block on DB, but not on feedback evaluation, depending on
#    1111 # FeedbackMode:
#    1112 record.feedback_and_future_results = self._handle_record(record=record)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\base\base_query_engine.py:53, in BaseQueryEngine.query(self, str_or_query_bundle)
#      51     if isinstance(str_or_query_bundle, str):
#      52         str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 53     query_result = self._query(str_or_query_bundle)
#      54 dispatch_event(QueryEndEvent())
#      55 return query_result
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\query_engine\retriever_query_engine.py:190, in RetrieverQueryEngine._query(self, query_bundle)
#     186 with self.callback_manager.event(
#     187     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     188 ) as query_event:
#     189     nodes = self.retrieve(query_bundle)
# --> 190     response = self._response_synthesizer.synthesize(
#     191         query=query_bundle,
#     192         nodes=nodes,
#     193     )
#     194     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     196 return response
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\base.py:242, in BaseSynthesizer.synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     236     query = QueryBundle(query_str=query)
#     238 with self._callback_manager.event(
#     239     CBEventType.SYNTHESIZE,
#     240     payload={EventPayload.QUERY_STR: query.query_str},
#     241 ) as event:
# --> 242     response_str = self.get_response(
#     243         query_str=query.query_str,
#     244         text_chunks=[
#     245             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     246         ],
#     247         **response_kwargs,
#     248     )
#     250     additional_source_nodes = additional_source_nodes or []
#     251     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\compact_and_refine.py:43, in CompactAndRefine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      39 # use prompt helper to fix compact text_chunks under the prompt limitation
#      40 # TODO: This is a temporary fix - reason it's temporary is that
#      41 # the refine template does not account for size of previous answer.
#      42 new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43 return super().get_response(
#      44     query_str=query_str,
#      45     text_chunks=new_texts,
#      46     prev_response=prev_response,
#      47     **response_kwargs,
#      48 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:183, in Refine.get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     179 for text_chunk in text_chunks:
#     180     if prev_response is None:
#     181         # if this is the first chunk, and text chunk already
#     182         # is an answer, then return it
# --> 183         response = self._give_response_single(
#     184             query_str, text_chunk, **response_kwargs
#     185         )
#     186     else:
#     187         # refine response if possible
#     188         response = self._refine_response_single(
#     189             prev_response, query_str, text_chunk, **response_kwargs
#     190         )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:238, in Refine._give_response_single(self, query_str, text_chunk, **response_kwargs)
#     234 if response is None and not self._streaming:
#     235     try:
#     236         structured_response = cast(
#     237             StructuredRefineResponse,
# --> 238             program(
#     239                 context_str=cur_text_chunk,
#     240                 **response_kwargs,
#     241             ),
#     242         )
#     243         query_satisfied = structured_response.query_satisfied
#     244         if query_satisfied:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\response_synthesizers\refine.py:84, in DefaultRefineProgram.__call__(self, *args, **kwds)
#      82     answer = answer.json()
#      83 else:
# ---> 84     answer = self._llm.predict(
#      85         self._prompt,
#      86         **kwds,
#      87     )
#      88 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:274, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     270 self.span_enter(
#     271     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     272 )
#     273 try:
# --> 274     result = func(*args, **kwargs)
#     275 except BaseException as e:
#     276     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\llm.py:430, in LLM.predict(self, prompt, **prompt_args)
#     428 if self.metadata.is_chat_model:
#     429     messages = self._get_messages(prompt, **prompt_args)
# --> 430     chat_response = self.chat(messages)
#     431     output = chat_response.message.content or ""
#     432 else:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:606, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     601     # TODO(piotrm): need to track costs of awaiting the ret in the
#     602     # below.
#     604     return wrap_awaitable(rets, on_done=handle_done)
# --> 606 handle_done(rets=rets)
#     607 return rets
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:575, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper.<locals>.handle_done(rets)
#     562         records[ctx] = ctx.app.on_add_record(
#     563             ctx=ctx,
#     564             func=func,
#    (...)
#     571             existing_record=records.get(ctx)
#     572         )
#     574 if error is not None:
# --> 575     raise error
#     577 return records
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\instruments.py:508, in Instrument.tracked_method_wrapper.<locals>.tru_wrapper(*args, **kwargs)
#     503 try:
#     504     # Using sig bind here so we can produce a list of key-value
#     505     # pairs even if positional arguments were provided.
#     506     bindings: BoundArguments = sig.bind(*args, **kwargs)
# --> 508     rets, cost = Endpoint.track_all_costs_tally(
#     509         func, *args, **kwargs
#     510     )
#     512 except BaseException as e:
#     513     error = e
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:496, in Endpoint.track_all_costs_tally(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     481 @staticmethod
#     482 def track_all_costs_tally(
#     483     __func: CallableMaybeAwaitable[A, T],
#    (...)
#     489     **kwargs
#     490 ) -> Tuple[T, Cost]:
#     491     """
#     492     Track costs of all of the apis we can currently track, over the
#     493     execution of thunk.
#     494     """
# --> 496     result, cbs = Endpoint.track_all_costs(
#     497         __func,
#     498         *args,
#     499         with_openai=with_openai,
#     500         with_hugs=with_hugs,
#     501         with_litellm=with_litellm,
#     502         with_bedrock=with_bedrock,
#     503         **kwargs
#     504     )
#     506     if len(cbs) == 0:
#     507         # Otherwise sum returns "0" below.
#     508         costs = Cost()
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:477, in Endpoint.track_all_costs(_Endpoint__func, with_openai, with_hugs, with_litellm, with_bedrock, *args, **kwargs)
#     468         except Exception as e:
#     469             logger.debug(
#     470                 "Could not initialize endpoint %s. "
#     471                 "Possibly missing key(s). "
#    (...)
#     474                 e,
#     475             )
# --> 477 return Endpoint._track_costs(
#     478     __func, *args, with_endpoints=endpoints, **kwargs
#     479 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:574, in Endpoint._track_costs(_Endpoint__func, with_endpoints, *args, **kwargs)
#     571     callbacks.append(callback)
#     573 # Call the function.
# --> 574 result: T = __func(*args, **kwargs)
#     576 # Return result and only the callbacks created here. Outer thunks might
#     577 # return others.
#     578 return result, callbacks
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\core\llms\callbacks.py:144, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     128 dispatcher.event(
#     129     LLMChatStartEvent(
#     130         model_dict=_self.to_dict(),
#    (...)
#     134     )
#     135 )
#     136 event_id = callback_manager.on_event_start(
#     137     CBEventType.LLM,
#     138     payload={
#    (...)
#     142     },
#     143 )
# --> 144 f_return_val = f(_self, messages, **kwargs)
#     146 if isinstance(f_return_val, Generator):
#     147     # intercept the generator and add a callback to the end
#     148     def wrapped_gen() -> ChatResponseGen:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:296, in OpenAI.chat(self, messages, **kwargs)
#     294 else:
#     295     chat_fn = completion_to_chat_decorator(self._complete)
# --> 296 return chat_fn(messages, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:325, in BaseRetrying.iter(self, retry_state)
#     323     retry_exc = self.retry_error_cls(fut)
#     324     if self.reraise:
# --> 325         raise retry_exc.reraise()
#     326     raise retry_exc from fut.exception()
#     328 if self.wait:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:158, in RetryError.reraise(self)
#     156 def reraise(self) -> t.NoReturn:
#     157     if self.last_attempt.failed:
# --> 158         raise self.last_attempt.result()
#     159     raise self
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\jkutty\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\llama_index\llms\openai\base.py:362, in OpenAI._chat(self, messages, **kwargs)
#     360 client = self._get_client()
#     361 message_dicts = to_openai_message_dicts(messages)
# --> 362 response = client.chat.completions.create(
#     363     messages=message_dicts,
#     364     stream=False,
#     365     **self._get_model_kwargs(**kwargs),
#     366 )
#     367 openai_message = response.choices[0].message
#     368 message = from_openai_message(openai_message)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\trulens_eval\feedback\provider\endpoint\base.py:668, in Endpoint.wrap_function.<locals>.tru_wrapper(*args, **kwargs)
#     658 logger.debug(
#     659     "Calling instrumented method %s of type %s, "
#     660     "iscoroutinefunction=%s, "
#    (...)
#     663     inspect.isasyncgenfunction(func)
#     664 )
#     666 # Get the result of the wrapped function:
# --> 668 response = func(*args, **kwargs)
#     670 bindings = inspect.signature(func).bind(*args, **kwargs)
#     672 # Get all of the callback classes suitable for handling this
#     673 # call. Note that we stored this in the INSTRUMENT attribute of
#     674 # the wrapper method.
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_utils\_utils.py:277, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     275             msg = f"Missing required argument: {quote(missing[0])}"
#     276     raise TypeError(msg)
# --> 277 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\resources\chat\completions.py:579, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     548 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     549 def create(
#     550     self,
#    (...)
#     577     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     578 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 579     return self._post(
#     580         "/chat/completions",
#     581         body=maybe_transform(
#     582             {
#     583                 "messages": messages,
#     584                 "model": model,
#     585                 "frequency_penalty": frequency_penalty,
#     586                 "function_call": function_call,
#     587                 "functions": functions,
#     588                 "logit_bias": logit_bias,
#     589                 "logprobs": logprobs,
#     590                 "max_tokens": max_tokens,
#     591                 "n": n,
#     592                 "presence_penalty": presence_penalty,
#     593                 "response_format": response_format,
#     594                 "seed": seed,
#     595                 "stop": stop,
#     596                 "stream": stream,
#     597                 "temperature": temperature,
#     598                 "tool_choice": tool_choice,
#     599                 "tools": tools,
#     600                 "top_logprobs": top_logprobs,
#     601                 "top_p": top_p,
#     602                 "user": user,
#     603             },
#     604             completion_create_params.CompletionCreateParams,
#     605         ),
#     606         options=make_request_options(
#     607             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     608         ),
#     609         cast_to=ChatCompletion,
#     610         stream=stream or False,
#     611         stream_cls=Stream[ChatCompletionChunk],
#     612     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1232, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1218 def post(
#    1219     self,
#    1220     path: str,
#    (...)
#    1227     stream_cls: type[_StreamT] | None = None,
#    1228 ) -> ResponseT | _StreamT:
#    1229     opts = FinalRequestOptions.construct(
#    1230         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1231     )
# -> 1232     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:997, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     995 if retries > 0 and self._should_retry(err.response):
#     996     err.response.close()
# --> 997     return self._retry_request(
#     998         options,
#     999         cast_to,
#    1000         retries,
#    1001         err.response.headers,
#    1002         stream=stream,
#    1003         stream_cls=stream_cls,
#    1004     )
#    1006 # If the response is streamed then we need to explicitly read the response
#    1007 # to completion before attempting to access the response text.
#    1008 if not err.response.is_closed:
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1045, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1041 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1042 # different thread if necessary.
#    1043 time.sleep(timeout)
# -> 1045 return self._request(
#    1046     options=options,
#    1047     cast_to=cast_to,
#    1048     remaining_retries=remaining,
#    1049     stream=stream,
#    1050     stream_cls=stream_cls,
#    1051 )
#
# File ~\anaconda3\envs\jkutty\Lib\site-packages\openai\_base_client.py:1012, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1009         err.response.read()
#    1011     log.debug("Re-raising status error")
# -> 1012     raise self._make_status_error_from_response(err.response) from None
#    1014 return self._process_response(
#    1015     cast_to=cast_to,
#    1016     options=options,
#    (...)
#    1019     stream_cls=stream_cls,
#    1020 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-3.5-turbo in organization org-n0G63sO89mOIG13HXDCrrwfQ on requests per min (RPM): Limit 3, Used 3, Requested 1. Please try again in 20s. Visit https://platform.openai.com/account/rate-limits to learn more. You can increase your rate limit by adding a payment method to your account at https://platform.openai.com/account/billing.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}

# %%
tru.get_leaderboard(app_ids=[])
# Out:
#                           latency  total_cost
# app_id
# Automerging Query Engine     11.0         0.0

# %%
# launches on http://localhost:8501/
tru.run_dashboard()
# Out:
# Starting dashboard ...
# Config file already exists. Skipping writing process.
# Credentials file already exists. Skipping writing process.
# Dashboard already running at path:   Network URL: http://192.168.1.11:8501
# <Popen: returncode: None args: ['streamlit', 'run', '--server.headless=True'...>
